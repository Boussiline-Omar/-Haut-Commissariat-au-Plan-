# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("Individu.csv")
data.head()
# Out:
#    reg  pro  mil  MEN_PRO  NOR_MEN  LIEN_CM  natio  sexe  AGE1  AGE5  ...  \
# 0    2   21    2        1        1        0      1     2   NaN    55  ...
# 1    2   21    2        1        2        4      1     1   NaN    25  ...
# 2    2   21    2        1        3        4      1     1   NaN    65  ...
# 3    2   21    2        1        4        4      1     1   NaN    25  ...
# 4   10  106    2        2        1        2      1     1   1.0     5  ...
#
#    FP_DIP_GG  TY_ACT  PROF_SGG  PROF_GG  STAT_PROF  ACT_SECTION  ACT_SECTEUR  \
# 0        NaN     2.0       NaN      NaN        NaN          NaN          NaN
# 1        NaN     4.0       NaN      NaN        NaN          NaN          NaN
# 2        2.0     3.0       NaN      NaN        NaN          NaN          NaN
# 3        NaN     0.0      28.0      9.0        1.0         12.0          2.0
# 4        NaN     NaN       NaN      NaN        NaN          NaN          NaN
#
#    TRAV_LIEU  TRAV_TRANS       pds
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99962 entries, 0 to 99961
# Data columns (total 45 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   reg            99962 non-null  int64
#  1   pro            99962 non-null  int64
#  2   mil            99962 non-null  int64
#  3   MEN_PRO        99962 non-null  int64
#  4   NOR_MEN        99962 non-null  int64
#  5   LIEN_CM        99962 non-null  int64
#  6   natio          99962 non-null  int64
#  7   sexe           99962 non-null  int64
#  8   AGE1           18857 non-null  float64
#  9   AGE5           99962 non-null  int64
#  10  E_MAT          20681 non-null  float64
#  11  ENF_VIV        21803 non-null  float64
#  12  ENF_DEC        21803 non-null  float64
#  13  ENF_VIV_12M    21803 non-null  float64
#  14  ENF_DEC_12M    21803 non-null  float64
#  15  HANDI_VIS      99962 non-null  int64
#  16  HANDI_AUD      99962 non-null  int64
# ...

# %%
data.discrib
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16580\1707298032.py in ?()
# ----> 1 data.discrib
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'discrib'

# %%
data.describ()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16580\1611311239.py in ?()
# ----> 1 data.describ()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'describ'

# %%
data.describ()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16580\1611311239.py in ?()
# ----> 1 data.describ()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'describ'

# %%
data.describe()
# Out:
#                 reg           pro           mil       MEN_PRO       NOR_MEN  \
# count  99962.000000  99962.000000  99962.000000  99962.000000  99962.000000
# mean       6.469068     68.703007      1.401232   9995.582131      3.667744
# std        3.446152     34.528845      0.490150   5776.312834      2.211281
# min        1.000000     11.000000      1.000000      1.000000      1.000000
# 25%        3.000000     37.000000      1.000000   4979.250000      2.000000
# 50%        6.000000     67.000000      1.000000   9965.000000      3.000000
# 75%        9.000000     97.000000      2.000000  14995.000000      5.000000
# max       12.000000    127.000000      2.000000  20000.000000      9.000000
#
#             LIEN_CM         natio          sexe          AGE1          AGE5  \
# count  99962.000000  99962.000000  99962.000000  18857.000000  99962.000000
# mean       3.170985      1.068666      1.498309      0.992364     37.481043
# ...

# %%
data.shape
# Out:
# (99962, 45)

# %%
print(pd.isnull(data))
# Out:
#          reg    pro    mil  MEN_PRO  NOR_MEN  LIEN_CM  natio   sexe   AGE1  \
# 0      False  False  False    False    False    False  False  False   True
# 1      False  False  False    False    False    False  False  False   True
# 2      False  False  False    False    False    False  False  False   True
# 3      False  False  False    False    False    False  False  False   True
# 4      False  False  False    False    False    False  False  False  False
# ...      ...    ...    ...      ...      ...      ...    ...    ...    ...
# 99957  False  False  False    False    False    False  False  False   True
# 99958  False  False  False    False    False    False  False  False   True
# 99959  False  False  False    False    False    False  False  False  False
# 99960  False  False  False    False    False    False  False  False   True
# 99961  False  False  False    False    False    False  False  False   True
#
# ...
