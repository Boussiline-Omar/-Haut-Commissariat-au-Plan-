# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('C:\\Users\\HP\\Desktop\\HCP\\RGPH_projet\\outputs\\menage_predictions.csv')
# Affichage des premières lignes du DataFrame
print(data.head())
# Out:
#    reg  MEN_PRO  milieu  province  taille_menage  score_vulnerabilite  \
# 0  1.0        1     1.0      51.0              7             3.746131
# 1  1.0        2     2.0      51.0              8             5.065530
# 2  1.0        3     2.0      51.0              6             5.302330
# 3  1.0        4     2.0      51.0              8             5.727273
# 4  1.0        5     2.0      51.0             10             5.705263
#
#    classe_vulnerabilite  pred_classe  proba_non_vuln  proba_vuln  \
# 0                     1            1        0.001727    0.895672
# 1                     2            2        0.000440    0.012508
# 2                     2            2        0.000221    0.012756
# 3                     2            2        0.000036    0.008693
# 4                     2            2        0.000000    0.009284
#
#    proba_tres_vuln
# 0         0.102601
# 1         0.987052
# 2         0.987023
# 3         0.991271
# 4         0.990716

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250013 entries, 0 to 250012
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   reg                   250013 non-null  float64
#  1   MEN_PRO               250013 non-null  int64
#  2   milieu                250013 non-null  float64
#  3   province              250013 non-null  float64
#  4   taille_menage         250013 non-null  int64
#  5   score_vulnerabilite   250013 non-null  float64
#  6   classe_vulnerabilite  250013 non-null  int64
#  7   pred_classe           250013 non-null  int64
#  8   proba_non_vuln        250013 non-null  float64
#  9   proba_vuln            250013 non-null  float64
#  10  proba_tres_vuln       250013 non-null  float64
# dtypes: float64(7), int64(4)
# memory usage: 21.0 MB
#                  reg        MEN_PRO         milieu       province  \
# ...

# %%
print(data.filter(like='predicted').head())
# Affichage de la distribution des prédictions
plt.figure(figsize=(10, 6))
plt.title('Distribution des Prédictions de Ménage')
plt.xlabel('Nombre de Ménages Prédit')
plt.ylabel('Fréquence')
plt.grid(axis='y', alpha=0.75)
plt.show()
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]
